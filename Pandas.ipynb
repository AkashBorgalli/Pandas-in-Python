# %% [markdown]
# ## Pandas Basic

# %%
import pandas as pd

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
newrecords = df.head(6)

# %%
newrecords
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
newrecords.to_csv("newrecords.csv")

# %%
pd.read_csv("newrecords.csv")
# Out:
#    Unnamed: 0  Id  MSSubClass MSZoning  LotFrontage  LotArea Street  Alley  \
# 0           0   1          60       RL         65.0     8450   Pave    NaN
# 1           1   2          20       RL         80.0     9600   Pave    NaN
# 2           2   3          60       RL         68.0    11250   Pave    NaN
# 3           3   4          70       RL         60.0     9550   Pave    NaN
# 4           4   5          60       RL         84.0    14260   Pave    NaN
# 5           5   6          50       RL         85.0    14115   Pave    NaN
#
#   LotShape LandContour  ... PoolArea PoolQC  Fence MiscFeature MiscVal MoSold  \
# 0      Reg         Lvl  ...        0    NaN    NaN         NaN       0      2
# 1      Reg         Lvl  ...        0    NaN    NaN         NaN       0      5
# 2      IR1         Lvl  ...        0    NaN    NaN         NaN       0      9
# 3      IR1         Lvl  ...        0    NaN    NaN         NaN       0      2
# ...

# %%
## see appended columns in last ## Pls scroll
## Skipped rows
pd.read_csv("newrecords.csv",header=None,names=['Sachin','Virat','JP','Dhoni'],skiprows=[3,4])
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Sachin  \
# ...

# %%
## na_values will replace the particular value as NaN
df = pd.read_csv("train.csv",na_values=['RL','IR1'])
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60      NaN         65.0     8450   Pave   NaN      Reg
# 1        2          20      NaN         80.0     9600   Pave   NaN      Reg
# 2        3          60      NaN         68.0    11250   Pave   NaN      NaN
# 3        4          70      NaN         60.0     9550   Pave   NaN      NaN
# 4        5          60      NaN         84.0    14260   Pave   NaN      NaN
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60      NaN         62.0     7917   Pave   NaN      Reg
# 1456  1457          20      NaN         85.0    13175   Pave   NaN      Reg
# 1457  1458          70      NaN         66.0     9042   Pave   NaN      Reg
# 1458  1459          20      NaN         68.0     9717   Pave   NaN      Reg
# 1459  1460          20      NaN         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
##It only gives description of numerical data
# min is 0th percentile
# max is 100th percentile
# percentile: sort the column first in ascending order then calculate percentile
## Data which is available at 25percentile it shows that
## It represents indexes
## you can say like 1460(count) datas id 50th percentile would be 730
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       309 non-null    object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       976 non-null    object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
## Here columns parameter behaves like which columns you need
df.to_csv("newrecordswith3columns.csv",index=False,header=False,sep="#",columns=['YearBuilt',"SaleCondition","SalePrice"])

# %%
pd.read_csv("newrecordswith3columns.csv",sep="#")
# Out:
#       2003   Normal  208500
# 0     1976   Normal  181500
# 1     2001   Normal  223500
# 2     1915  Abnorml  140000
# 3     2000   Normal  250000
# 4     1993   Normal  143000
# ...    ...      ...     ...
# 1454  1999   Normal  175000
# 1455  1978   Normal  210000
# 1456  1941   Normal  266500
# 1457  1950   Normal  142125
# 1458  1965   Normal  147500
#
# [1459 rows x 3 columns]

# %%
df = pd.read_csv("train.csv")
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.tail(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#To list columns
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df['LandSlope']
# Out:
# 0       Gtl
# 1       Gtl
# 2       Gtl
# 3       Gtl
# 4       Gtl
#        ...
# 1455    Gtl
# 1456    Gtl
# 1457    Gtl
# 1458    Gtl
# 1459    Gtl
# Name: LandSlope, Length: 1460, dtype: object

# %%
## to retrive particular data from column
df['LandSlope'][1456]
# Out:
# 'Gtl'

# %%
## pandas has 2 types series and dataframe
## series is like from entire data 1 column or 1 row is considered as series
type(df['LandSlope'])
# Out:
# pandas.core.series.Series

# %%
## To convert it into dataframe
df[['GarageCars']]
# Out:
#       GarageCars
# 0              2
# 1              2
# 2              2
# 3              3
# 4              3
# ...          ...
# 1455           2
# 1456           2
# 1457           1
# 1458           1
# 1459           1
#
# [1460 rows x 1 columns]

# %%
## when you pass your column name into a list then your data will be transformed in dataframe
type(df[['GarageCars']])
# Out:
# pandas.core.frame.DataFrame

# %%
## to get multiple data
df[['GarageCars','GarageFinish','Utilities']]
# Out:
#       GarageCars GarageFinish Utilities
# 0              2          RFn    AllPub
# 1              2          RFn    AllPub
# 2              2          RFn    AllPub
# 3              3          Unf    AllPub
# 4              3          RFn    AllPub
# ...          ...          ...       ...
# 1455           2          RFn    AllPub
# 1456           2          Unf    AllPub
# 1457           1          RFn    AllPub
# 1458           1          Unf    AllPub
# 1459           1          Fin    AllPub
#
# [1460 rows x 3 columns]

# %% [markdown]
# ## Excel

# %%
# !pip install xlrd

# %%
# !pip install openpyxl

# %%
df = pd.read_excel("C:/Users/91706/Downloads/student-data.xlsx")
df.head(6)
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera          None      1618.5
# 1  Government  Germany  Carretera          None      1321.0
# 2   Midmarket   France  Carretera          None      2178.0
# 3   Midmarket  Germany  Carretera          None       888.0
# 4   Midmarket   Mexico  Carretera          None      2470.0
# 5  Government  Germany  Carretera          None      1513.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts     Sales  \
# 0                    3          20      32370.0        0.0   32370.0
# 1                    3          20      26420.0        0.0   26420.0
# 2                    3          15      32670.0        0.0   32670.0
# 3                    3          15      13320.0        0.0   13320.0
# 4                    3          15      37050.0        0.0   37050.0
# 5                    3         350     529550.0        0.0  529550.0
#
# ...

# %%
df = pd.read_excel("C:/Users/91706/Downloads/student-data.xlsx",sheet_name='EmpData')
df.head(6)
# Out:
#    Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 0  677509        Drs.       Lois              H    Walker      F
# 1  940761         Ms.     Brenda              S  Robinson      F
# 2  428945         Dr.        Joe              W  Robinson      M
# 3  408351        Drs.      Diane              I     Evans      F
# 4  193819         Mr.   Benjamin              R   Russell      M
# 5  499687         Mr.    Patrick              F    Bailey      M
#
#                          E Mail     Father's Name       Mother's Name  \
# 0       lois.walker@hotmail.com     Donald Walker        Helen Walker
# 1     brenda.robinson@gmail.com  Raymond Robinson       Judy Robinson
# 2        joe.robinson@gmail.com    Scott Robinson  Stephanie Robinson
# 3         diane.evans@yahoo.com       Jason Evans      Michelle Evans
# 4  benjamin.russell@charter.net   Gregory Russell   Elizabeth Russell
# 5        patrick.bailey@aol.com      Ralph Bailey        Laura Bailey
#
# ...

# %% [markdown]
# ## HTML

# %%
## It basically tries to find <tr><tb> tag bydefault
df2 = pd.read_html("https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool")

# %%
type(df2)
# Out:
# list

# %%
len(df2)
# Out:
# 6

# %%
df2[0]
# Out:
#        Season   Age                                   Team  \
# 0     2008-09  19.0  Did Not Play (other pro league—Spain)
# 1     2009-10  20.0                                    OKC
# 2     2010-11  21.0                                    OKC
# 3     2011-12  22.0                                    OKC
# 4     2012-13  23.0                                    OKC
# 5     2013-14  24.0                                    OKC
# 6     2014-15  25.0                                    OKC
# 7     2015-16  26.0                                    OKC
# 8     2016-17  27.0                                    TOT
# 9     2016-17  27.0                                    ORL
# 10    2016-17  27.0                                    TOR
# 11    2017-18  28.0                                    TOR
# 12    2018-19  29.0                                    TOR
# 13    2019-20  30.0                                    TOR
# 14    2020-21  31.0                                    LAC
# ...

# %%
df2[3]
# Out:
#        Season   Age Team   Lg  Pos      G     GS      MP     FG     FGA  ...  \
# 0     2009-10  20.0  OKC  NBA   PF    6.0    0.0   153.0   20.0    35.0  ...
# 1     2010-11  21.0  OKC  NBA   PF   17.0   17.0   490.0   67.0   145.0  ...
# 2     2011-12  22.0  OKC  NBA   PF   20.0   20.0   569.0   84.0   159.0  ...
# 3     2012-13  23.0  OKC  NBA   PF   11.0   11.0   366.0   59.0   135.0  ...
# 4     2013-14  24.0  OKC  NBA   PF   17.0   17.0   581.0   87.0   147.0  ...
# 5     2015-16  26.0  OKC  NBA   PF   18.0   18.0   602.0   85.0   163.0  ...
# 6     2016-17  27.0  TOR  NBA   PF   10.0   10.0   307.0   60.0   130.0  ...
# 7     2017-18  28.0  TOR  NBA   PF   10.0    9.0   260.0   30.0    72.0  ...
# 8     2018-19  29.0  TOR  NBA    C   24.0    0.0   500.0   92.0   193.0  ...
# 9     2019-20  30.0  TOR  NBA    C   11.0    0.0   251.0   63.0   110.0  ...
# 10    2020-21  31.0  LAC  NBA    C    2.0    0.0    18.0    3.0     6.0  ...
# ...

# %%
df2[4].to_csv("players.csv",index=False)

# %%
## Data as raw enabled and take from link
df3 = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
k = """{
"name" : "Akash",
"phone_no" : "90876",
"company":["Capgemini","EY"]
}
"""

# %%
import json

# %%
s = json.loads(k)

# %%
s
# Out:
# {'name': 'Akash', 'phone_no': '90876', 'company': ['Capgemini', 'EY']}

# %%
pd.DataFrame(s)
# Out:
#     name phone_no    company
# 0  Akash    90876  Capgemini
# 1  Akash    90876         EY

# %%
pd.DataFrame(s,columns=['company'])
# Out:
#      company
# 0  Capgemini
# 1         EY

# %%
# !pip install requests

# %%
import requests

# %%
res = requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
res
# Out:
# <Response [200]>

# %%
js = res.json()

# %%
js[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42102',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42102/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42102/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42102/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/issues/42102',
#  'id': 924727199,
#  'node_id': 'MDU6SXNzdWU5MjQ3MjcxOTk=',
#  'number': 42102,
#  'title': 'Indexing MultiIndex with duplicates return Series instead of raw value ',
#  'user': {'login': 'LucasG0',
#   'id': 44552904,
#   'node_id': 'MDQ6VXNlcjQ0NTUyOTA0',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/44552904?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/LucasG0',
#   'html_url': 'https://github.com/LucasG0',
# ...

# %%
## to access from this dictionary
js[0]['title']
# Out:
# 'Indexing MultiIndex with duplicates return Series instead of raw value '

# %%
for i in js:
    print(i['title'])
# Out:
# Indexing MultiIndex with duplicates return Series instead of raw value
# BUG: `Styler.hide_columns()` does not hide index name row
# REF: use only inherit_names in CategoricalIndex
# BUG: Adding Series to empty DataFrame can reset dtype to float64
# CLN: use fused type for lib.has_infs
# REGR: Subclassing `Styler` and addressing `from_custom_template`
# [WIP] BUG: fix `Series.argsort`
# REGR: undocumented astype("category").astype(str) type inconsistency between pandas 1.1 & 1.2
# BUG: groupby any/all raising with pd.NA object data
# PERF/CLN: to_csv
# When change default dtype for empty Series?
# CI: disable auto-cancel for master branch
# BUG: error writing sparse DataFrame to HDF
# BUG: pd.to_datetime(infer_datetime_format=True) drops timezone
# DOC: How to use storage_option param here to integrate with GCP bucket?
# BUG: rolling std can't handle mixture of (relatively) big and small numbers
# BUG: avoid unnecessary casting in CategoricalIndex.reindex
# ...

# %%
pd.DataFrame(js,columns=['url','title'])
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
df4 = pd.DataFrame(js)
df4
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
df4.to_csv('json_dump.csv')

# %%
k = js[0]['user']
k
# Out:
# {'login': 'LucasG0',
#  'id': 44552904,
#  'node_id': 'MDQ6VXNlcjQ0NTUyOTA0',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/44552904?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/LucasG0',
#  'html_url': 'https://github.com/LucasG0',
#  'followers_url': 'https://api.github.com/users/LucasG0/followers',
#  'following_url': 'https://api.github.com/users/LucasG0/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/LucasG0/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/LucasG0/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/LucasG0/subscriptions',
#  'organizations_url': 'https://api.github.com/users/LucasG0/orgs',
#  'repos_url': 'https://api.github.com/users/LucasG0/repos',
#  'events_url': 'https://api.github.com/users/LucasG0/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/LucasG0/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
t = []
for i in k:
    t.append(i)
print(t)
# Out:
# ['login', 'id', 'node_id', 'avatar_url', 'gravatar_id', 'url', 'html_url', 'followers_url', 'following_url', 'gists_url', 'starred_url', 'subscriptions_url', 'organizations_url', 'repos_url', 'events_url', 'received_events_url', 'type', 'site_admin']

# %%
f = pd.DataFrame(k,columns=t,index=[0])
f
# Out:
#      login        id               node_id  \
# 0  LucasG0  44552904  MDQ6VXNlcjQ0NTUyOTA0
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/445529...
#
#                                     url                    html_url  \
# 0  https://api.github.com/users/LucasG0  https://github.com/LucasG0
#
#                                     followers_url  \
# 0  https://api.github.com/users/LucasG0/followers
#
#                                        following_url  \
# 0  https://api.github.com/users/LucasG0/following...
#
#                                            gists_url  \
# 0  https://api.github.com/users/LucasG0/gists{/gi...
#
#                                          starred_url  \
# 0  https://api.github.com/users/LucasG0/starred{/...
#
#                                    subscriptions_url  \
# 0  https://api.github.com/users/LucasG0/subscript...
#
#                            organizations_url  \
# ...

# %%
lst = []
for i in range(len(js)):
    lst.append(js[i]['user'])

# %%
lst
# Out:
# [{'login': 'LucasG0',
#   'id': 44552904,
#   'node_id': 'MDQ6VXNlcjQ0NTUyOTA0',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/44552904?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/LucasG0',
#   'html_url': 'https://github.com/LucasG0',
#   'followers_url': 'https://api.github.com/users/LucasG0/followers',
#   'following_url': 'https://api.github.com/users/LucasG0/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/LucasG0/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/LucasG0/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/LucasG0/subscriptions',
#   'organizations_url': 'https://api.github.com/users/LucasG0/orgs',
#   'repos_url': 'https://api.github.com/users/LucasG0/repos',
#   'events_url': 'https://api.github.com/users/LucasG0/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/LucasG0/received_events',
#   'type': 'User',
# ...

# %%
pd.DataFrame(lst)
# Out:
#               login        id               node_id  \
# 0           LucasG0  44552904  MDQ6VXNlcjQ0NTUyOTA0
# 1          attack68  24256554  MDQ6VXNlcjI0MjU2NTU0
# 2      jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 3        JBGreisman   6944142  MDQ6VXNlcjY5NDQxNDI=
# 4        mzeitlin11  37011898  MDQ6VXNlcjM3MDExODk4
# 5          attack68  24256554  MDQ6VXNlcjI0MjU2NTU0
# 6          attack68  24256554  MDQ6VXNlcjI0MjU2NTU0
# 7   simonjayhawkins  13159005  MDQ6VXNlcjEzMTU5MDA1
# 8        mzeitlin11  37011898  MDQ6VXNlcjM3MDExODk4
# 9         lithomas1  47963215  MDQ6VXNlcjQ3OTYzMjE1
# 10         Rubtsowa  36762665  MDQ6VXNlcjM2NzYyNjY1
# 11       fangchenli   7614606  MDQ6VXNlcjc2MTQ2MDY=
# 12     raphaelquast  22773387  MDQ6VXNlcjIyNzczMzg3
# 13          i-aki-y   9190086  MDQ6VXNlcjkxOTAwODY=
# 14      KayvanShah1  59110083  MDQ6VXNlcjU5MTEwMDgz
# 15         auderson  48577571  MDQ6VXNlcjQ4NTc3NTcx
# 16     jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# ...

# %%
## Different Approach
json_data = pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')
data = pd.DataFrame.from_records(json_data['user'])
data.head(6)
# Out:
#           login        id               node_id  \
# 0       LucasG0  44552904  MDQ6VXNlcjQ0NTUyOTA0
# 1      attack68  24256554  MDQ6VXNlcjI0MjU2NTU0
# 2  jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 3    JBGreisman   6944142  MDQ6VXNlcjY5NDQxNDI=
# 4    mzeitlin11  37011898  MDQ6VXNlcjM3MDExODk4
# 5      attack68  24256554  MDQ6VXNlcjI0MjU2NTU0
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/445529...
# 1  https://avatars.githubusercontent.com/u/242565...
# 2  https://avatars.githubusercontent.com/u/807896...
# 3  https://avatars.githubusercontent.com/u/694414...
# 4  https://avatars.githubusercontent.com/u/370118...
# 5  https://avatars.githubusercontent.com/u/242565...
#
#                                          url                         html_url  \
# 0       https://api.github.com/users/LucasG0       https://github.com/LucasG0
# 1      https://api.github.com/users/attack68      https://github.com/attack68
# ...

# %%
ds = pd.read_csv("players.csv")
ds
# Out:
#        Season   Age Team   Lg  Pos      G       MP   PER    TS%   3PAr  ...  \
# 0     2009-10  20.0  OKC  NBA   PF   73.0   1323.0  15.2  0.562  0.005  ...
# 1     2010-11  21.0  OKC  NBA   PF   82.0   2216.0  17.7  0.579  0.002  ...
# 2     2011-12  22.0  OKC  NBA   PF   66.0   1792.0  19.0  0.556  0.006  ...
# 3     2012-13  23.0  OKC  NBA   PF   80.0   2486.0  19.4  0.612  0.073  ...
# 4     2013-14  24.0  OKC  NBA   PF   81.0   2666.0  19.6  0.576  0.061  ...
# 5     2014-15  25.0  OKC  NBA   PF   64.0   2116.0  16.6  0.549  0.261  ...
# 6     2015-16  26.0  OKC  NBA   PF   78.0   2500.0  13.9  0.533  0.212  ...
# 7     2016-17  27.0  TOT  NBA   PF   79.0   2422.0  16.4  0.566  0.323  ...
# 8     2016-17  27.0  ORL  NBA   PF   56.0   1710.0  17.5  0.569  0.304  ...
# 9     2016-17  27.0  TOR  NBA   PF   23.0    712.0  13.8  0.556  0.369  ...
# 10    2017-18  28.0  TOR  NBA   PF   76.0   2093.0  14.7  0.574  0.379  ...
# ...

# %%
ds.to_pickle("my_pickel")

# %%
# !pip install tables

# %%
h5_Data=pd.HDFStore('players_hdstorefile.h5')

# %%
h5_Data['obj1'] = ds
# Out:
# C:\Users\91706\anaconda3\envs\AI\lib\site-packages\IPython\core\interactiveshell.py:3441: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['Season', 'Team', 'Lg', 'Pos'], dtype='object')]
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
h5_Data['obj1']
# Out:
#        Season   Age Team   Lg  Pos      G       MP   PER    TS%   3PAr  ...  \
# 0     2009-10  20.0  OKC  NBA   PF   73.0   1323.0  15.2  0.562  0.005  ...
# 1     2010-11  21.0  OKC  NBA   PF   82.0   2216.0  17.7  0.579  0.002  ...
# 2     2011-12  22.0  OKC  NBA   PF   66.0   1792.0  19.0  0.556  0.006  ...
# 3     2012-13  23.0  OKC  NBA   PF   80.0   2486.0  19.4  0.612  0.073  ...
# 4     2013-14  24.0  OKC  NBA   PF   81.0   2666.0  19.6  0.576  0.061  ...
# 5     2014-15  25.0  OKC  NBA   PF   64.0   2116.0  16.6  0.549  0.261  ...
# 6     2015-16  26.0  OKC  NBA   PF   78.0   2500.0  13.9  0.533  0.212  ...
# 7     2016-17  27.0  TOT  NBA   PF   79.0   2422.0  16.4  0.566  0.323  ...
# 8     2016-17  27.0  ORL  NBA   PF   56.0   1710.0  17.5  0.569  0.304  ...
# 9     2016-17  27.0  TOR  NBA   PF   23.0    712.0  13.8  0.556  0.369  ...
# 10    2017-18  28.0  TOR  NBA   PF   76.0   2093.0  14.7  0.574  0.379  ...
# ...

# %%
## serilaization
h5_Data.put('obj2',ds,format='table')

# %%
## desirialization
h5_Data.select('obj2',where=['index >= 10 and index <= 15'])
# Out:
#      Season   Age Team   Lg  Pos      G       MP   PER    TS%   3PAr  ...  \
# 10  2017-18  28.0  TOR  NBA   PF   76.0   2093.0  14.7  0.574  0.379  ...
# 11  2018-19  29.0  TOR  NBA    C   74.0   2010.0  18.7  0.582  0.193  ...
# 12  2019-20  30.0  TOR  NBA    C   55.0   1485.0  17.3  0.583  0.272  ...
# 13  2020-21  31.0  LAC  NBA    C   41.0    955.0  18.2  0.585  0.315  ...
# 14   Career   NaN  NaN  NBA  NaN  849.0  24064.0  17.2  0.571  0.186  ...
# 15      NaN   NaN  NaN  NaN  NaN    NaN      NaN   NaN    NaN    NaN  ...
#
#     Unnamed: 19   OWS   DWS    WS  WS/48  Unnamed: 24  OBPM  DBPM  BPM  VORP
# 10          NaN   2.1   3.0   5.1  0.117          NaN  -0.1   0.0 -0.1   1.0
# 11          NaN   2.8   3.3   6.1  0.146          NaN   0.2   0.1  0.2   1.2
# 12          NaN   1.2   2.7   3.9  0.126          NaN   0.1   0.0  0.1   0.8
# 13          NaN   1.7   1.3   3.0  0.150          NaN   1.3  -0.5  0.8   0.7
# ...

# %%
## Data as raw enabled and take from link
df3 = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df3.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df3.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df3.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df3.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df3.dtypes[df3.dtypes== 'object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df3[df3.dtypes[df3.dtypes== 'object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df5 = df3[df3.dtypes[df3.dtypes== 'object'].index]
df5.describe()
# Out:
#                        Name   Sex  Ticket    Cabin Embarked
# count                   891   891     891      204      889
# unique                  891     2     681      147        3
# top     Canavan, Miss. Mary  male  347082  B96 B98        S
# freq                      1   577       7        4      644

# %%
df3[['PassengerId','Pclass']]
# Out:
#      PassengerId  Pclass
# 0              1       3
# 1              2       1
# 2              3       3
# 3              4       1
# 4              5       3
# ..           ...     ...
# 886          887       2
# 887          888       1
# 888          889       3
# 889          890       1
# 890          891       3
#
# [891 rows x 2 columns]

# %%
## As this is a list so u can do all operations in this
## as this is in series format
df3['Name'][5:10]
# Out:
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
df3['Akash']="Borgalli"

# %%
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df3['Akash']=df3['PassengerId']

# %%
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.Categorical(df3['Sex'])
# Out:
# ['male', 'female', 'female', 'female', 'male', ..., 'male', 'female', 'female', 'male', 'male']
# Length: 891
# Categories (2, object): ['female', 'male']

# %%
pd.Categorical(df3['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
df3['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df3['Pclass'].isnull().count()
# Out:
# 891

# %%
## row selection where Cabin values are null
ser = df3['Cabin'][df3['Cabin'].isnull() == True]

# %%
ser.index
# Out:
# Int64Index([  0,   2,   4,   5,   7,   8,   9,  12,  13,  14,
#             ...
#             878, 880, 881, 882, 883, 884, 885, 886, 888, 890],
#            dtype='int64', length=687)

# %%
## row level selection
df3.iloc[ser.index]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
## row level selection
df3.iloc[[1,2,3,8,10,6]]
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 8             9         1       3
# 10           11         1       3
# 6             7         0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
#
#     Parch            Ticket     Fare Cabin Embarked  Akash
# 1       0          PC 17599  71.2833   C85        C      2
# 2       0  STON/O2. 3101282   7.9250   NaN        S      3
# ...

# %%
## to find how many records there are null values
len(ser.index)
# Out:
# 687

# %%
## To find persons name who paid the highest(fare)
df3[df3['Fare'] == max(df3['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#      Akash
# 258    259
# 679    680
# 737    738

# %%
df3[df3['Fare'] == max(df3['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
## Addition of two columns
df3['Addition'] = df3['PassengerId'] + df3['Age']

# %%
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df6 = pd.read_table("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv")
df6
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df6.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
df7 = pd.read_table("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/beer.txt")
df7
# Out:
#        name calories sodium alcohol cost
# 0              Budweiser 144 15 4.7 0.43
# 1                Schlitz 151 19 4.9 0.43
# 2              Lowenbrau 157 15 0.9 0.48
# 3             Kronenbourg 170 7 5.2 0.73
# 4               Heineken 152 11 5.0 0.77
# 5          Old_Milwaukee 145 23 4.6 0.28
# 6             Augsberger 175 24 5.5 0.40
# 7   Srohs_Bohemian_Style 149 27 4.7 0.42
# 8             Miller_Lite 99 10 4.3 0.43
# 9         Budweiser_Light 113 8 3.7 0.40
# 10                 Coors 140 18 4.6 0.44
# 11           Coors_Light 102 15 4.1 0.46
# 12        Michelob_Light 135 11 4.2 0.50
# 13                 Becks 150 19 4.7 0.76
# 14                  Kirin 149 6 5.0 0.79
# 15      Pabst_Extra_Light 68 15 2.3 0.38
# 16                 Hamms 139 19 4.4 0.43
# 17   Heilemans_Old_Style 144 24 4.9 0.43
# 18     Olympia_Goled_Light 72 6 2.9 0.46
# 19           Schlitz_Light 97 7 4.2 0.47

# %%
df8 = pd.read_table("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv")
df8

# %%
df9 = pd.read_table("https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv")
